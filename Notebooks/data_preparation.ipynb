# %%
# import libraries 
import _sqlite3
import pandas as pd

# %% [markdown]
# Read sqlite data file

# %%
# Read sqlite query results into a pandas DataFrame
con = _sqlite3.connect("/database.sqlite.zip")
df = pd.read_sql_query("SELECT * from match", con)

# Verify that result of SQL query is stored in the dataframe
print(df.head())

con.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Read sqlite query results into a pandas DataFrame
# ----> 2 con = _sqlite3.connect("/database.sqlite.zip")
#       3 df = pd.read_sql_query("SELECT * from match", con)
#       5 # Verify that result of SQL query is stored in the dataframe
#
# OperationalError: unable to open database file
